# %%
import tensorflow as tf
import pandas as pd
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
# Out:
# 2025-05-29 04:10:15.505343: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-29 04:10:15.917417: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-29 04:10:16.193127: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748491816.492984   18354 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748491816.561943   18354 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1748491817.383013   18354 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748491817.383052   18354 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748491817.383058   18354 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748491817.383062   18354 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-29 04:10:17.428754: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Importamos los datos y los dividimos en Entrenamiento y Validación

# %%
''' 
mnist = tf.keras.datasets.mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()
'''
#Leemos el conjuntos de datos
df = pd.read_csv('data_1.csv', delimiter=';')

# %% [markdown]
# Escalamos los datos para que estén en [0-1]

# %%
X_train = tf.keras.utils.normalize(X_train, axis= 1)
X_test = tf.keras.utils.normalize(X_test, axis= 1)

# %% [markdown]
# Creamos el modelo de Red Neuronal, la entrada son imágenes de 28x28, la primer capa flatten hace que la matriz se transforme en un vector.
# Esta Red tiene 2 capas ocultas de 16 neuronas cada una y una capa de salida de 10 neurona.

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten(input_shape= (28, 28)))
#no es un grid es una linea de 784 pixeles
model.add(tf.keras.layers.Dense(16, activation= 'relu'))
# dense son las capas del medio
model.add(tf.keras.layers.Dense(16, activation= 'relu'))
model.add(tf.keras.layers.Dense(10, activation= 'softmax'))

# %% [markdown]
# Compilamos el modelo utilizando como función de pérdida crossentropy y como métrica accuracy

# %%
model.compile(optimizer= 'adam', loss= 'sparse_categorical_crossentropy', metrics= ['accuracy'])

# %% [markdown]
# Entrenamos el modelo

# %%
model.fit(X_train, y_train, epochs= 10)

# %% [markdown]
# Validamos el modelo con los datos que reservamos para validación

# %%
loss,acuracy = model.evaluate(X_test, y_test)

print(loss)
print(acuracy)

# %%
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)
conf_matrix = confusion_matrix(y_test, predicted_labels)
# Imprimir la matriz de confusión
print("Matriz de Confusión:")
print(conf_matrix)

# Visualizar la matriz de confusión
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
